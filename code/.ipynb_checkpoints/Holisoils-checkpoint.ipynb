# %% [markdown]
# <font size = "4">**HoliSoils - Orchidee optimization**</font>

# %%
# %matplotlib inline
import os
import sys
module_path = os.path.abspath(os.path.join(''))
if module_path not in sys.path:
    sys.path.append(module_path+"/python")

from python import Optimization_HS as Opt

# Example with predefined objectives

#BES -- bio economy strategy
#BDS -- biodiversity strategy
#NFS -- National forest strategy

BDS = Opt.OptGUI("BDS",True,"TestData_Holisoils_KE.csv")
# Out:
# Zip already existed
# 'Using CLP'
# objectives for BDS loaded
# 'Defining objectives'
# 'Aggregating stand wise'
# 'Aggregating year wise'
# 'Objectives added'
# 'Calculating objective ranges'
# HTML(value='<h2>Instructions</h2>')
# HTML(value='<p>This interface allows you to adjust sliders for different variables. You can change the values …
# HTML(value='<h2>Reference point</h2>')
# VBox(children=(FloatSlider(value=6081.3427379589775, description='Total soil C', layout=Layout(width='95%'), m…
# <h2>Constraint values</h2>
# Checkbox(value=False, description='Show Constraint Values', tooltip='Check to display the constraint value sli…
# Box(children=(Output(),), layout=Layout(height='auto', overflow='auto', padding='10px', width='100%'))
# <h2>Enabled constraints</h2>
# interactive(children=(Output(),), _dom_classes=('widget-interact',))
# Button(description='Optimize', style=ButtonStyle())
# Output()
